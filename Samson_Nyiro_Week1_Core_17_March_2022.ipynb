# %% [markdown]
# <a href="https://colab.research.google.com/github/ch1b4d4/Samson_Nyiro_Week1_Core_17_March_2022/blob/main/Samson_Nyiro_Week1_Core_17_March_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url = 'http://bit.ly/VariableDefinitions'
url1 = 'http://bit.ly/FinancialDataset'

# %% [markdown]
# # Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading data

# %%
df = pd.read_csv('http://bit.ly/VariableDefinitions')
df2 = pd.read_csv('http://bit.ly/FinancialDataset')
df3 = pd.read_csv('http://bit.ly/FinancialDataset')

# %%
# Display Output
df
# Out:
#       Variable Definitions                                         Unnamed: 1
# 0                  country                         Country interviewee is in.
# 1                     year                           Year survey was done in.
# 2                 uniqueid             Unique identifier for each interviewee
# 3            location_type                     Type of location: Rural, Urban
# 4         cellphone_access  If interviewee has access to a cellphone: Yes, No
# 5           household_size               Number of people living in one house
# 6        age_of_respondent                         The age of the interviewee
# 7     gender_of_respondent                Gender of interviewee: Male, Female
# 8   relationship_with_head  The interviewee’s relationship with the head o...
# 9           marital_status  The martial status of the interviewee: Married...
# 10         education_level  Highest level of education: No formal educatio...
# ...

# %%
# Display Output
df2.head()
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %% [markdown]
# # 1. Research Question
# - Find out which individuals are most likely to have or use a bank account

# %% [markdown]
# # 2. The metric for success
# - Measured when we remove the outliers and produce a list of people who are most likely to have  a bank account
# - Produce outputs and visualizations of the banking sector showing the most profitable sectors, the sector growing fastest and the trends in the banking industry currently.

# %% [markdown]
# # 3. Context
# - Financial Inclusion remains one of the main obstacles to economic and human development in Africa. For example, across Kenya, Rwanda, Tanzania, and Uganda only 9.1 million adults (or 13.9% of the adult population) have access to or use a commercial bank account.
#
# - Traditionally, access to bank accounts has been regarded as an indicator of financial inclusion. Despite the proliferation of mobile money in Africa and the growth of innovative fintech solutions, banks still play a pivotal role in facilitating access to financial services. Access to bank accounts enables households to save and facilitate payments while also helping businesses build up their credit-worthiness and improve their access to other financial services. Therefore, access to bank accounts is an essential contributor to long-term economic growth.

# %% [markdown]
# # 4. Recording the Experimental
# - Derive the appropriate variables
# - Define and establish all the relationships the variables in the dataset has
# - Determine what factors coud affect our variables

# %%
# Checking the Data
# Determining the no. of records in our dataset
print(f"The number of columns is: { df2.shape[1]} and the rows are: {df2.shape[0]}")
# Out:
# The number of columns is: 13 and the rows are: 23524

# %%
# Previewing the top of our dataset
df2.head(5)
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# Previewing the bottom of our dataset
df2.tail(5)
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 23519               Yes             4.0            48.0               Female
# 23520               Yes             2.0            27.0               Female
# 23521               Yes             5.0            27.0               Female
# 23522               Yes             7.0            30.0               Female
# 23523               Yes            10.0            20.0                 Male
#
#       The relathip with head        marital_status  Level of Educuation  \
# ...

# %%
# Checking whether each column has an appropriate datatype
#
df2.dtypes
# Out:
# country                    object
# year                        int64
# uniqueid                   object
# Has a Bank account         object
# Type of Location           object
# Cell Phone Access          object
# household_size            float64
# Respondent Age            float64
# gender_of_respondent       object
# The relathip with head     object
# marital_status             object
# Level of Educuation        object
# Type of Job                object
# dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23510 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   Has a Bank account      23488 non-null  object
#  4   Type of Location        23509 non-null  object
#  5   Cell Phone Access       23513 non-null  object
#  6   household_size          23496 non-null  float64
#  7   Respondent Age          23490 non-null  float64
#  8   gender_of_respondent    23490 non-null  object
#  9   The relathip with head  23520 non-null  object
#  10  marital_status          23492 non-null  object
#  11  Level of Educuation     23495 non-null  object
#  12  Type of Job             23494 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ MB

# %% [markdown]
# # External Data Validation

# %%
# Making sure that the countries in question are represented in the dataset
nchi = ['Kenya', 'Rwanda', 'Tanzania', 'Uganda']
df2['country'].isin(nchi).any()
# Out:
# True

# %%
df2['country'].unique()
# The list shows availability of null values hence needing to drop them as they would not add any value to this research
# Out:
# array(['Kenya', 'Rwanda', 'Tanzania', nan, 'Uganda'], dtype=object)

# %%
# Confirming that the data set represents data from 2016 - 2018
df2['year'].unique()
#The data shows that we have some wrong data representation with the availability of Cle which
# need to be dropped
# Out:
# array([2018, 2029, 2056, 2016, 2039, 2017])

# %%
# Checking for consinstency in the data values and variables
df2['gender_of_respondent'].unique()

# the null values need to be dropped from this column
# Out:
# array(['Female', 'Male', nan], dtype=object)

# %%
df2['Has a Bank account'].unique()

# the null values need to be dropped from this column
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df2['Cell Phone Access'].unique()

# the null values need to be dropped from this column
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %% [markdown]
# # Data Cleaning

# %%
# Dropping all the null values from the dataset

df2.dropna(inplace = True)
df2.shape
# Out:
# (23343, 13)

# %%
# Checking for missing values in the dataset demographic data.
 
# Creating a function to check
def missing_values(data):
 
 # identifying the missing values from the demographic data dataset
 #
 miss = data.isnull().sum().sort_values(ascending = False)
 # finding the percentage of missing values
 percentage = (data.isnull().sum() / len(data)).sort_values(ascending = False)
 # storing  total missing values in percentage in dataframe
 #
 missing_data = pd.DataFrame({'Total' : miss, 'Percentage' : percentage})
 #if the percentage is 0, indicates no missing values hence removed
 #
 missing_data.drop(missing_data[missing_data['Percentage'] == 0].index, inplace = True)
 
 return missing_data
 
missing_values(df2)
# Out:
# Empty DataFrame
# Columns: [Total, Percentage]
# Index: []

# %%
# Checking for duplicate valiues
df2.duplicated().any()
# Out:
# False

# %%
# Cleaning up the Year Column values
miaka = ['2029', '2056', '2039']

# Removal of irrelevant data

# df_2.drop(df_2.loc[df_2['year'] > 2018].index , inplace=True)
df2.drop(df2.loc[df2['year'] > 2018].index, inplace = True)

# Display the updated dataset without the dropped rows

df2['year'].unique()
# df_2.head(5)
# Out:
# array([2018, 2016, 2017])

# %%
# Checking the Unique ID column for any duplicates 

len(df2['uniqueid'].unique())
# Out:
# 8687

# %%
# Comparing the Shape of the whole dataset with the column unique ID for any duplicates

df2.shape
# Out:
# (23340, 13)

# %%
# Displaying whether there are duplicate values

df2['uniqueid'].duplicated().any()
# Out:
# True

# %%
# Droping the duplicate values in the unique ID column

clean = df2.drop_duplicates(subset=['uniqueid'])

# %%
# df2['uniqueid'].duplicated().
clean.shape
# Out:
# (8687, 13)

# %%
# Confirming that all the duplicate values in the unique ID column have been eliminated

clean['uniqueid'].duplicated().any()
# Out:
# False

# %% [markdown]
# - The Duplicate values on the Unique ID column were deleted as they do not add value to the research. Users should be unique for the analysis to mae sense hence need for each user to be uniquely identified.

# %% [markdown]
# # Data Analysis
# - Tidying the Data Set

# %%
clean.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'Has a Bank account', 'Type of Location',
#        'Cell Phone Access', 'household_size', 'Respondent Age',
#        'gender_of_respondent', 'The relathip with head', 'marital_status',
#        'Level of Educuation', 'Type of Job'],
#       dtype='object')

# %%
clean.describe()
# Out:
#               year  household_size  Respondent Age
# count  8687.000000     8687.000000     8687.000000
# mean   2017.395649        4.123057       39.564752
# std       0.918455        2.249452       16.957544
# min    2016.000000        1.000000       16.000000
# 25%    2016.000000        2.000000       26.000000
# 50%    2018.000000        4.000000       35.000000
# 75%    2018.000000        6.000000       50.000000
# max    2018.000000       21.000000       96.000000

# %%
# Checking for outliers
# checking to see if any values appear True if so they are outliers
#
Q1 = clean.quantile(0.25)
Q3 = clean.quantile(0.75)

IQR = Q3 - Q1


(clean < (Q1 - 1.5 * IQR)) |(clean > (Q3 + 1.5 * IQR))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   # Remove the CWD from sys.path while we load stuff.
#        Cell Phone Access  Has a Bank account  Level of Educuation  \
# 0                  False               False                False
# 1                  False               False                False
# 2                  False               False                False
# 3                  False               False                False
# 4                  False               False                False
# ...                  ...                 ...                  ...
# 14798              False               False                False
# 14799              False               False                False
# ...

# %%
# Checking for Outliers
#
import seaborn as sns
sns.boxplot(clean['Respondent Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The Boxplot shows some demographic above the age of 90 in the dataset. I choose to remove them from my focus of study as they are not prone to open new bank accounts or offer any profitability despite that demographic needing access to pensions and or government assistance subsidies

# %%
# Finding minimum and maximum values in the age column
min, mid, max = clean['Respondent Age'].quantile([0.01, 0.5, 0.80])
min, max, mid
# Out:
# (16.0, 55.0, 35.0)

# %%
# Displaying the values where age is above 55
min_cust = clean[clean['Respondent Age'] >= max].head()
min_cust
# Out:
#    country  year     uniqueid Has a Bank account Type of Location  \
# 1    Kenya  2018   uniqueid_2                 No            Rural
# 9    Kenya  2018  uniqueid_10                 No            Urban
# 11   Kenya  2018  uniqueid_12                Yes            Rural
# 12   Kenya  2018  uniqueid_13                 No            Rural
# 29   Kenya  2018  uniqueid_30                 No            Rural
#
#    Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 1                 No             5.0            70.0               Female
# 9                Yes             3.0            76.0               Female
# 11               Yes             3.0            69.0                 Male
# 12                No             6.0            64.0               Female
# 29                No             7.0            58.0               Female
#
#    The relathip with head           marital_status  Level of Educuation  \
# ...

# %%
# Displaying the values where age is between 16 and 35
max_cust = clean[(clean['Respondent Age'] >= min) & (clean['Respondent Age'] <= mid) ]
max_cust.head()
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
# 5   Kenya  2018  uniqueid_6                 No            Rural
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
# 5                No             7.0            26.0               Female
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# Displaying the values where age is between 16 and 35
mid_cust = clean[(clean['Respondent Age'] >= mid) & (clean['Respondent Age'] <= max) ]
mid_cust.head()
# Out:
#    country  year     uniqueid Has a Bank account Type of Location  \
# 7    Kenya  2018   uniqueid_8                 No            Rural
# 8    Kenya  2018   uniqueid_9                Yes            Rural
# 10   Kenya  2018  uniqueid_11                 No            Rural
# 15   Kenya  2018  uniqueid_16                 No            Rural
# 16   Kenya  2018  uniqueid_17                 No            Urban
#
#    Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 7                Yes             1.0            42.0               Female
# 8                Yes             3.0            54.0                 Male
# 10               Yes             5.0            40.0               Female
# 15               Yes             7.0            38.0                 Male
# 16               Yes             1.0            47.0               Female
#
#    The relathip with head           marital_status  Level of Educuation  \
# ...

# %%
# New dataset with the outliers removed
df_2 = clean[(clean['Respondent Age'] >= min) & (clean['Respondent Age'] <= max)]
df_2.head()
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
# 5   Kenya  2018  uniqueid_6                 No            Rural
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
# 5                No             7.0            26.0               Female
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
sns.boxplot(df_2['Respondent Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df_2['household_size'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Finding minimum and maximum values in the age column
min, mid, max = df_2['household_size'].quantile([0.01, 0.5, 0.80])
min, max, mid
# Out:
# (1.0, 6.0, 4.0)

# %%
# New dataset with the outliers removed
households = df_2[(df_2['household_size'] >= min) & (df_2['household_size'] <= max)]
households.head()
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 7   Kenya  2018  uniqueid_8                 No            Rural
# 8   Kenya  2018  uniqueid_9                Yes            Rural
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 7               Yes             1.0            42.0               Female
# 8               Yes             3.0            54.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
households.shape
# Out:
# (5910, 13)

# %%
# The new boxplot without the outliers 

sns.boxplot(households['household_size'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Sorting the data so that we have them in alphabetical order

households = households.sort_values(
     by="Respondent Age",
     ascending=True
 )

households.head(10)
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 2872    Kenya  2018  uniqueid_2873                 No            Rural
# 951     Kenya  2018   uniqueid_952                 No            Urban
# 2803    Kenya  2018  uniqueid_2804                 No            Rural
# 3836    Kenya  2018  uniqueid_3837                 No            Rural
# 4655    Kenya  2018  uniqueid_4656                 No            Urban
# 13601  Rwanda  2016  uniqueid_7534                 No            Rural
# 14533  Rwanda  2016  uniqueid_8466                 No            Rural
# 2403    Kenya  2018  uniqueid_2404                 No            Rural
# 13720  Rwanda  2016  uniqueid_7653                 No            Urban
# 5924    Kenya  2018  uniqueid_5925                 No            Urban
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 2872                 No             6.0            16.0                 Male
# ...

# %% [markdown]
# # Exploratory Analysis

# %%
households.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'Has a Bank account', 'Type of Location',
#        'Cell Phone Access', 'household_size', 'Respondent Age',
#        'gender_of_respondent', 'The relathip with head', 'marital_status',
#        'Level of Educuation', 'Type of Job'],
#       dtype='object')

# %%
# Ploting the univariate summaries and recording our observations
#
# Frequency table
households.value_counts()
# Out:
# country  year  uniqueid       Has a Bank account  Type of Location  Cell Phone Access  household_size  Respondent Age  gender_of_respondent  The relathip with head  marital_status           Level of Educuation  Type of Job
# Kenya    2018  uniqueid_1     Yes                 Rural             Yes                3.0             24.0            Female                Spouse                  Married/Living together  Secondary education  Self employed           1
#                uniqueid_765   No                  Rural             Yes                5.0             40.0            Male                  Head of Household       Married/Living together  Primary education    Farming and Fishing     1
#                uniqueid_776   No                  Urban             Yes                3.0             26.0            Female                Head of Household       Married/Living together  Primary education    Remittance Dependent    1
# ...

# %%
# Finding the Number of people without a bank account in each country
solution_1 = households.groupby(['Has a Bank account', 'country']).mean()
solution_1
# Out:
#                               year  household_size  Respondent Age
# Has a Bank account country
# No                 Kenya    2018.0        3.600804       32.197254
#                    Rwanda   2016.0        4.015773       33.258044
# Yes                Kenya    2018.0        3.060633       34.775923
#                    Rwanda   2016.0        3.955224       35.358209

# %%
households.boxplot()

# %% [markdown]
# # Univariate Analysis

# %%
households.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'Has a Bank account', 'Type of Location',
#        'Cell Phone Access', 'household_size', 'Respondent Age',
#        'gender_of_respondent', 'The relathip with head', 'marital_status',
#        'Level of Educuation', 'Type of Job'],
#       dtype='object')

# %%
# The output below shows the type of location the responders are based and what status they have regarding having a bank account
#  and decision making abilities to owning one.

households[['country', 'Type of Location', 'The relathip with head', 'Has a Bank account']].value_counts()
# Out:
# country  Type of Location  The relathip with head  Has a Bank account
# Kenya    Rural             Head of Household       No                    820
# Rwanda   Rural             Head of Household       No                    684
# Kenya    Urban             Head of Household       No                    657
#                                                    Yes                   550
#          Rural             Spouse                  No                    484
# Rwanda   Rural             Spouse                  No                    453
# Kenya    Urban             Spouse                  No                    323
#          Rural             Child                   No                    313
#                            Head of Household       Yes                   227
# Rwanda   Rural             Child                   No                    215
# Kenya    Urban             Child                   No                    178
# ...

# %% [markdown]
# # Insights
# - The above output displays the location of the respondents.
# - These respondendts are grouped by their location, their bank owning status and their relationship with the head of the house.
# - The relationship with the head of the house is able to let the marketing team know how and who to sell as this representst the prime decision maker

# %% [markdown]
# # Focus of Study
# - This study will focus on house hold owners as they are the majority of the respondents and because most decision makers in an african home are them.

# %%
# How many Household owners have a bank account and what is their location

acc_loc = households[households["The relathip with head"] == 'Head of Household']["Has a Bank account"].value_counts()
acc_loc
# Out:
# No     2224
# Yes     901
# Name: Has a Bank account, dtype: int64

# %%
# The details of househld leaders who have no bank account
acc_loc_no = households[(households["The relathip with head"] == 'Head of Household') & (households["Has a Bank account"]=='No') & (["Type of Location"])]
acc_loc_no.head()
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 12650  Rwanda  2016  uniqueid_6583                 No            Rural
# 5051    Kenya  2018  uniqueid_5052                 No            Urban
# 4188    Kenya  2018  uniqueid_4189                 No            Urban
# 5070    Kenya  2018  uniqueid_5071                 No            Rural
# 5073    Kenya  2018  uniqueid_5074                 No            Urban
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 12650               Yes             1.0            16.0               Female
# 5051                 No             2.0            16.0               Female
# 4188                 No             1.0            16.0                 Male
# 5070                 No             1.0            17.0                 Male
# 5073                 No             5.0            17.0                 Male
#
#       The relathip with head        marital_status Level of Educuation  \
# ...

# %%
# The details of househld leaders who have a bank account
acc_loc_yes = households[(households["The relathip with head"] == 'Head of Household') & (households["Has a Bank account"]=='Yes') & (["Type of Location"])]
acc_loc_yes.head()
# Out:
#      country  year       uniqueid Has a Bank account Type of Location  \
# 2338   Kenya  2018  uniqueid_2339                Yes            Urban
# 3387   Kenya  2018  uniqueid_3388                Yes            Urban
# 5775   Kenya  2018  uniqueid_5776                Yes            Urban
# 595    Kenya  2018   uniqueid_596                Yes            Urban
# 1796   Kenya  2018  uniqueid_1797                Yes            Urban
#
#      Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 2338               Yes             1.0            18.0                 Male
# 3387               Yes             1.0            18.0                 Male
# 5775               Yes             1.0            19.0               Female
# 595                Yes             1.0            19.0               Female
# 1796               Yes             1.0            19.0               Female
#
#      The relathip with head        marital_status Level of Educuation  \
# ...

# %%
# Mean age of househld leaders who have no bank account
acc_loc_no['Respondent Age'].mean()
# Out:
# 36.827338129496404

# %%
# Mean age of househld leaders who have a bank account
acc_loc_yes['Respondent Age'].mean()
# Out:
# 36.26637069922309

# %%
# Location of the househld leaders who have no bank account
acc_loc_no[['Type of Location', 'country']].value_counts()
# Out:
# Type of Location  country
# Rural             Kenya      820
#                   Rwanda     684
# Urban             Kenya      657
#                   Rwanda      63
# dtype: int64

# %%
# Location of the househld leaders who have a bank account
acc_loc_yes[['Type of Location', 'country']].value_counts()
# Out:
# Type of Location  country
# Urban             Kenya      550
# Rural             Kenya      227
#                   Rwanda      83
# Urban             Rwanda      41
# dtype: int64

# %%
# Do the Household leaders with a bank acount have a cell phone, what is their education level and their source of income?
acc_loc_no[['Level of Educuation', 'Cell Phone Access', 'Type of Job']].value_counts()
# Out:
# Level of Educuation              Cell Phone Access  Type of Job
# Primary education                Yes                Informally employed             451
#                                                     Farming and Fishing             320
# Secondary education              Yes                Informally employed             158
# Primary education                Yes                Self employed                   145
# No formal education              Yes                Farming and Fishing             122
#                                                     Informally employed             110
# Secondary education              Yes                Self employed                    98
#                                                     Farming and Fishing              92
# Primary education                No                 Informally employed              91
#                                  Yes                Remittance Dependent             63
# ...

# %%
# Do the Household leaders with a bank acount have a cell phone, what is their education level and their source of income?
acc_loc_yes[['Level of Educuation', 'Cell Phone Access', 'Type of Job']].value_counts()
# Out:
# Level of Educuation              Cell Phone Access  Type of Job
# Secondary education              Yes                Self employed                   93
#                                                     Formally employed Private       69
#                                                     Informally employed             67
# Primary education                Yes                Farming and Fishing             62
#                                                     Self employed                   61
#                                                     Informally employed             57
# Secondary education              Yes                Farming and Fishing             56
# Tertiary education               Yes                Formally employed Government    50
# Secondary education              Yes                Formally employed Government    45
# Vocational/Specialised training  Yes                Formally employed Government    43
# ...

# %%
# Plot to display the House Hold leaders who have a bank account and their educational level in regards to their income/type of employment
import seaborn as sns

sns.set(rc = {'figure.figsize':(25,8)})

sns.countplot(x="Level of Educuation", hue="Type of Job", data=acc_loc_yes);

# %%
# Location and the country of those house hold leaders with a bank account

sns.countplot(x="Type of Location", hue="country", data=acc_loc_yes);

# %% [markdown]
# # Insights
# The plot above shows that the house hold leaders who have a bank account are:
# - predominantly educated with most of them having secondary education, vocational training, primary training and lastly tertiary training
# - The Leaders too are mainly self employed but the list is closely followed by those formally employed by the government. The other huge group represents those who are privately employed
# - The data also shows that most household leaders in Urban and Rural Kenya have bank accounts as opposed to Rwanda where the numbers are low

# %%
# Plot to display the House Hold leaders who do not have a bank account and their educational level 
# in regards to their income/type of employment

import seaborn as sns

sns.set(rc = {'figure.figsize':(25,8)})

sns.countplot(x="Level of Educuation", hue="Type of Job", data=acc_loc_no);

# %%
# Location and the country of those house hold leaders with a bank account

sns.countplot(x="Type of Location", hue="country", data=acc_loc_no);

# %% [markdown]
# # Insights
# - Regarding the household heads who do not have a bank account:
# i. Most of them have no educaation with a small number with primary or secondary education
# ii. This group is also majorly informally employed and the other huge group set work in the farming and fishing sector
# - The data also shows that most household leaders in Urban and Rural Kenya do not have bank accounts as opposed to Rwanda where the numbers are low in rural Rwanda but Urban Rwanda represents an intersting aspect as their urban residents seem to have low number representation to those without bank accounts compared to kenya's urban dwellers.

# %% [markdown]
# # Bivariate Analysis
# - For this next step of the analysis, the data will be edited into numerical values for the analysis to be performed

# %%
# Conversion of The data set and parameters
# Rural to represent 1.0
# Urban to represent 2.0
df2.loc[df2['Type of Location'] == 'Rural', 'Type of Location'] = '1.0'
df2.loc[df2['Type of Location'] == 'Urban', 'Type of Location'] = '2.0'

# %%
df2['Type of Location'] = df2['Type of Location'].astype(float)

# %%
# Conversion of The data set and parameters
# Male to represent 2.0
# Female to represent 1.0

df2.loc[df2['gender_of_respondent'] == 'Male', 'gender_of_respondent'] = '2.0'
df2.loc[df2['gender_of_respondent'] == 'Female', 'gender_of_respondent'] = '1.0'

# %%
df2['gender_of_respondent'] = df2['gender_of_respondent'].astype(float)

# %%
# Conversion of The data set and parameters
# Has a Bank account to represent 2.0
# Has no Bank account to represent 1.0

df2.loc[df2['Has a Bank account'] == 'Male', 'Has a Bank account'] = '2.0'
df2.loc[df2['Has a Bank account'] == 'Female', 'Has a Bank account'] = '1.0'

# %%
df2['Has a Bank account'] = df2['Has a Bank account'].astype(float)

# %%
# Conversion of The data set and parameters
# has a cell phone to represent 2.0
# Has no cell phone to represent 1.0

df2.loc[df2['Cell Phone Access'] == 'Yes', 'Cell Phone Access'] = '2.0'
df2.loc[df2['Cell Phone Access'] == 'No', 'Cell Phone Access'] = '1.0'

# %%
df2['Cell Phone Access'] = df2['Cell Phone Access'].astype(float)

# %%
df2.head()
# Out:
#   country  year    uniqueid  Has a Bank account  Type of Location  \
# 0   Kenya  2018  uniqueid_1                 2.0               1.0
# 1   Kenya  2018  uniqueid_2                 1.0               1.0
# 2   Kenya  2018  uniqueid_3                 2.0               2.0
# 3   Kenya  2018  uniqueid_4                 1.0               1.0
# 4   Kenya  2018  uniqueid_5                 1.0               2.0
#
#    Cell Phone Access  household_size  Respondent Age  gender_of_respondent  \
# 0                2.0             3.0            24.0                   1.0
# 1                1.0             5.0            70.0                   1.0
# 2                2.0             5.0            26.0                   2.0
# 3                2.0             5.0            34.0                   1.0
# 4                1.0             8.0            26.0                   2.0
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23340 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23340 non-null  object
#  1   year                    23340 non-null  int64
#  2   uniqueid                23340 non-null  object
#  3   Has a Bank account      23340 non-null  float64
#  4   Type of Location        23340 non-null  float64
#  5   Cell Phone Access       23340 non-null  float64
#  6   household_size          23340 non-null  float64
#  7   Respondent Age          23340 non-null  float64
#  8   gender_of_respondent    23340 non-null  float64
#  9   The relathip with head  23340 non-null  object
#  10  marital_status          23340 non-null  object
#  11  Level of Educuation     23340 non-null  object
#  12  Type of Job             23340 non-null  object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 2.5+ MB

# %%
plt.scatter(acc_loc_no['Level of Educuation'], acc_loc_no['Respondent Age'])

# %%
acc_loc_no.corr()
# Out:
#                     year  household_size  Respondent Age
# year            1.000000       -0.173240       -0.071792
# household_size -0.173240        1.000000        0.124327
# Respondent Age -0.071792        0.124327        1.000000

# %%
acc_loc_yes.corr()
# Out:
#                     year  household_size  Respondent Age
# year            1.000000       -0.225058       -0.047808
# household_size -0.225058        1.000000        0.253543
# Respondent Age -0.047808        0.253543        1.000000

# %%
df2.corr()
# Out:
#                           year  Has a Bank account  Type of Location  \
# year                  1.000000            0.112622          0.214621
# Has a Bank account    0.112622            1.000000          0.088626
# Type of Location      0.214621            0.088626          1.000000
# Cell Phone Access    -0.066637            0.209512         -0.083635
# household_size       -0.052484           -0.023056         -0.274154
# Respondent Age       -0.018554            0.019601         -0.047614
# gender_of_respondent -0.000024            0.116058          0.013158
#
#                       Cell Phone Access  household_size  Respondent Age  \
# year                          -0.066637       -0.052484       -0.018554
# Has a Bank account             0.209512       -0.023056        0.019601
# Type of Location              -0.083635       -0.274154       -0.047614
# Cell Phone Access              1.000000        0.098177       -0.103969
# ...

# %% [markdown]
# # Insights
# - The correlation analysis do not give any useful insight for the data to provide any information to the analysts

# %% [markdown]
# # Multiple Regression Analysis

# %%
from sklearn import linear_model
# ,	'Cell Phone Access'	,'household_size',	'Respondent Age',	'gender_of_respondent' 
X = df2[['Cell Phone Access'	,'household_size',	'Respondent Age',	'gender_of_respondent' ]]
y = df2[['Has a Bank account']]

regr = linear_model.LinearRegression()
regr.fit(X, y)

print(regr.coef_)
# Out:
# [[ 0.16520374 -0.00613294  0.00073974  0.0671185 ]]

# %%
predicted = regr.predict([[2.0,2.0,2.0,2.0,2.0]])

print(predicted)
# Out:
# [[1.20646405]]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
import statsmodels.api as sm

#define response variable
y = df2['Has a Bank account']

#define explanatory variable
x = df2[['Type of Location', ]]

#add constant to predictor variables
x = sm.add_constant(x)

#fit linear regression model
model = sm.OLS(y, x).fit()

#view model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     Has a Bank account   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     184.8
# Date:                Sun, 20 Mar 2022   Prob (F-statistic):           6.39e-42
# Time:                        07:50:19   Log-Likelihood:                -8405.8
# No. Observations:               23340   AIC:                         1.682e+04
# Df Residuals:                   23338   BIC:                         1.683e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.0533      0.007    153.632      0.000       1.040       1.067
# ...

# %% [markdown]
# # Insights
# - The MLR shows that for a client to take a bank account then;
# Cell Phone Access',	'Cell Phone Access'	,'household_size',	'Respondent Age',	'gender_of_respondent' will have to increase by 0.08260187  0.08260187 -0.00613294  0.00073974  0.0671185 respectively
#
# - With further research, the predicted outcome is; 1.20646405
# which further confirms the conclusion as (1.20646405 + (0.16520374*1000) != 2.0 which represents no actual uptake of a bank account. Hence mentioning that the uptake is not easily affected by the other variables
#
# - It is also important to note that the gender of the respondent and their age do not offer ny value or insight to change in the uptake of the bank accounts. (1.20646405 + (-0.06*1000) != 2.0 and (1.20646405 + (0.07*1000) != 2.0
